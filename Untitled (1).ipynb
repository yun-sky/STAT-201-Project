# %%
library(tidyverse)
install.packages('ggcorrplot')
library(ggcorrplot)  #Allows to render correlation plot

# %%
rice_data <- read.csv("Rice_Cammeo_Osmancik.arff", header=FALSE, comment.char = "@")
clean_data <- rice_data[-c(0, 1, 2, 3, 4), ]
clean_data_2 <- type.convert(clean_data, as.is= TRUE)
colnames(clean_data_2) <- c("area", "perimeter", "major_axis_length", "minor_axis_length", "eccentricity", 
                            "convex_area", "Extent", "class")
head(clean_data_2)

binary_data<- clean_data_2 |>
     mutate(class = ifelse(class == "Cammeo",1,0))|>
    cor(use="complete.obs") 

head(binary_data)
tail(binary_data)

ggcorrplot(binary_data, 
           hc.order = TRUE, 
           type = "lower",
           lab = TRUE)
# Out:
#    area  perimeter major_axis_length minor_axis_length eccentricity convex_area
# 5  15231 525.579   229.7499          85.09379          0.9288820    15617
# 6  14656 494.311   206.0201          91.73097          0.8954050    15072
# 7  14634 501.122   214.1068          87.76829          0.9121181    14954
# 8  13176 458.343   193.3374          87.44839          0.8918609    13368
# 9  14688 507.167   211.7434          89.31245          0.9066909    15262
# 10 13479 477.016   200.0531          86.65029          0.9013283    13786
#    Extent    class
# 5  0.5728955 Cammeo
# 6  0.6154363 Cammeo
# 7  0.6932588 Cammeo
# 8  0.6406690 Cammeo
# 9  0.6460239 Cammeo
# 10 0.6578973 Cammeo
#                   area      perimeter major_axis_length minor_axis_length
# area              1.0000000 0.9664531 0.9030147          0.7878401
# perimeter         0.9664531 1.0000000 0.9718845          0.6298280
# major_axis_length 0.9030147 0.9718845 1.0000000          0.4520921
# ...
