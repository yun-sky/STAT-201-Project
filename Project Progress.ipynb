# %% [markdown]
# # Deliverable 3: Final Report Progress Tracker
# To check off a box, double click the markdon block to edit and put down X inside [ ]
#
# ### Submission
# - [ ] Submit final report (Only one member of you team needs to submit)
#     - the source Jupyter notebook (.ipynb file)
#     - the rendered final document (.html file)
# ### General Specifications
# - [ ] Maximum of 2000 words
# - [ ] use Jupyter to communicate the question asked
#     - [ ] communicate the analysis performed
#     - [ ] communicate the conclusion reached.
#
# ### Introduction
# - [X] Include introduction from the original proposal
# - [ ] Change things based on your own improved understanding of the project
#
# ### Methods and Results
# - [X] Include work from Preliminary results
# - [ ] Describe the methods you used to perform your analysis from beginning to end that narrates the code the does the analysis.
# - [ ] Include figures/table numbers and relevant units.
# #### Hypothesis Testing
# - [X] for $\mu$ `Perimeter` conducted hypothesis testing using the boostrap and t-distribution method
#     - [X] Included significance level, null hypothesis, and alternative hypothesis before starting the testing
#     - [X] calculated test-statistic and p-value
#     - [X] visualized null distribution with the p-value shaded and the test-statistic included
# - [X] for $\mu$ `Major Axis Length` conducted hypothesis testing using the boostrap and t-distribution method
#     - [X] Included significance level, null hypothesis, and alternative hypothesis before starting the testing
#     - [X] calculated test-statistic and p-value
#     - [X] visualized null distribution with the p-value shaded and the test-statistic included
# #### Confidence Intervals
# **Bootstrapping - Perimeter**
# - [ ] Calculate the confidence interval based on the given significance level.
# - [ ] report confidence interval
# - [ ] visualize distribution with confidence interval
#
# **t-distrution - Perimeter**
# - [X] Calculate the confidence interval based on the given significance level.
# - [X] report confidence interval
# - [ ] visualize distribution with confidence interval
#
# **Bootstrapping - Major Axis Length**
# - [ ] Calculate the confidence interval based on the given significance level.
# - [ ] report confidence interval
# - [ ] visualize distribution with confidence interval
#
# **t-distrution - Perimeter**
# - [ ] Calculate the confidence interval based on the given significance level.
# - [ ] report confidence interval
# - [ ] visualize distribution with confidence interval
#
#
#
# **Possible Analysis**
# - [ ] Calculate the power, type I error, and type II error of the hypothesis test
#
#
# #### Results
# - [ ] Explain whether boostrapping or asymptotics is more appropiate than the other.
#     - [ ] Explain why you think both methods gave you similar/different results
#     - [ ] Explain whether one is more trustworthy than the other
#
#
#
# ### Discussion
# - [ ] Summarize what you found
#     - [ ] Summarize the impact and implications of your findings
# - [ ] Discuss whether your results were what you expected to find
# - [ ] Discuss future questions/research this study could lead to.
#
# **Possible Discussion Points**
# - [ ] Discuss the reliability of our results using the power of our test
#
# ### References
# - [X] Include references from the proposal
#
# ### EXTRAS
# - [ ] Add $\alpha$
#
# ### Work Distribution
# - [X] major_axis_length mean (Bootstrap) -EMI
# - [X] perimeter mean (Bootstrap) -SKY
#
# - [X] major_axis_length mean (CLT) -NOUR
# - [X] perimeter mean (CLT) -SHAHBAZ
